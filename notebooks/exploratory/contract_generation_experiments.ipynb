# %% [markdown]
# ## Sample contract

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from importlib import reload  
import llm_programs
reload(llm_programs)

from llm_programs.tasks.contract_generation.redaction.generate import generate_contract
from llm_programs.programs.base import Gemini
from llm_programs.utils import *

# %%
engine = Gemini(model_name="gemini-2.0-flash")

# %%
info, description, contract = generate_contract(engine, debug=True)

# %%
print(wrap(contract))
# Out:
# **BOOK LICENSING AGREEMENT**
#
# This Book Licensing Agreement (the "Agreement") is made and entered
# into as of October 3, 2001 (the "Effective Date") by and between Oxford University Press ("OUP"),
# located at 1600 Amphitheatre Parkway, Mountain View, CA 94043, and Springer Nature ("SN").
#
# **1.
# Preamble / Recitals**
#
# WHEREAS, OUP is the owner of certain intellectual property rights in and to
# the book entitled "Advanced Banana Stand Construction" (the "Work"); and
#
# WHEREAS, SN is engaged in
# the business of publishing and distributing books in electronic format; and
#
# WHEREAS, OUP desires to
# grant to SN, and SN desires to receive from OUP, a license to publish and distribute a revised
# edition of the Work in e-book format, subject to the terms and conditions hereinafter set forth.
# NOW, THEREFORE, in consideration of the mutual covenants and agreements hereinafter set forth, the
# parties agree as follows:
#
# **2. Definitions**
#
# ...
